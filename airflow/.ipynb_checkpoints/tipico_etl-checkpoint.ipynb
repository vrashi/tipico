# %%
pip install apache-airflow
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
#from airflow.utils.dates import days_ago
import requests
import csv
from datetime import datetime
import pandas as pd
import os

# %%
url = 'https://trading-api.tipico.us/v1/pds/lbc/events/live?licenseId=US-NJ&lang=en&limit=18'
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# [{'id': 815139,
#   'startTime': '2024-05-26T14:00:00Z',
#   'messageTime': '2024-05-26T22:09:24.236Z',
#   'sportType': 'TENNIS',
#   'matchState': 'ONGOING',
#   'participants': [{'id': 85914,
#     'name': 'Hinojosa Gomez J / Reasco Gonzalez M E',
#     'position': 'HOME',
#     'abbreviation': 'HRE'},
#    {'id': 85913,
#     'name': 'Bozovic A / Wong H Y C',
#     'position': 'AWAY',
#     'abbreviation': 'BWO'}],
#   'status': 'RUNNING',
#   'marketCount': 25,
#   'group': {'id': 3434,
#    'name': 'ITF Dominican Republic 03A Doubles (W)',
#    'parentGroup': {'id': 106,
#     'name': 'ITF Women',
#     'parentGroup': {'id': 21, 'name': 'Tennis'}}},
#   'markets': [{'id': '759e6bee-19c9-3f0e-a4d4-0cb8d121eaab',
#     'name': 'Bozovic A / Wong H Y C To Win A Set',
#     'type': 'away-to-win-a-set',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'outcomes': [{'id': 'ecab54a5-c4e0-3d8a-9753-8ad237a8c8d5',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 1.93,
#       'formatAmerican': '-107',
#       'status': 'ONGOING',
#       'trueOdds': 1.934579439},
#      {'id': '5355a951-540a-340e-97de-846d5e7d35e4',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 1.74,
#       'formatAmerican': '-135',
#       'status': 'ONGOING',
#       'trueOdds': 1.74074074}]},
#    {'id': '6f623109-97b8-3755-bfc6-c68f5e69693d',
#     'name': 'Bozovic A / Wong H Y C To Win Exactly One Set',
#     'type': 'away-to-win-exactly-one-set',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'outcomes': [{'id': '8f0186d0-5965-35cd-a1f5-4673443add35',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 4.35,
#       'formatAmerican': '335',
#       'status': 'ONGOING',
#       'trueOdds': 4.35},
#      {'id': 'f8f4f04d-f383-3e92-b4c2-a7c2e27b5318',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 1.16,
#       'formatAmerican': '-625',
#       'status': 'ONGOING',
#       'trueOdds': 1.16}]},
#    {'id': 'f2e6b405-4e67-3eea-bdcb-5bfe15eed5a0',
#     'name': 'Bozovic A / Wong H Y C To Win Exactly Two Sets',
#     'type': 'away-to-win-exactly-two-sets',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'outcomes': [{'id': 'c4337b81-06c1-3dce-be2f-af18a3bf4df4',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 3.0,
#       'formatAmerican': '200',
#       'status': 'ONGOING',
#       'trueOdds': 3.0},
#      {'id': 'd0161c68-6dc9-3401-ad18-e65cae10e24d',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 1.32,
#       'formatAmerican': '-312',
#       'status': 'ONGOING',
#       'trueOdds': 1.32051282}]},
#    {'id': 'c665d28c-3333-37ae-a792-cb1963bd37fd',
#     'name': '2nd Set 4th Game To Deuce',
#     'type': 'deuce-in-game',
#     'parameters': ['2', '4'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '4', 'type': 'LONG'}],
#     'outcomes': [{'id': 'c9982d00-9dbe-3e6e-b692-95a176110da4',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 3.0,
#       'formatAmerican': '200',
#       'status': 'ONGOING',
#       'trueOdds': 3.0},
#      {'id': 'e56e9522-bda4-32a1-8012-b83f1fd6adfa',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 1.32,
#       'formatAmerican': '-312',
#       'status': 'ONGOING',
#       'trueOdds': 1.32051282}]},
#    {'id': '48f026d9-274b-3ad0-98e1-c6eb23e12352',
#     'name': 'First 2 Points in 2nd Set 4th Game',
#     'type': 'first-game-points-in-set',
#     'parameters': ['2', '4', '2'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '4', 'type': 'LONG'},
#      {'key': 'POINT_NUMBER', 'value': '2', 'type': 'LONG'}],
#     'outcomes': [{'id': '1275fc39-dd0c-3cce-8865-76cd304db791',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E',
#       'isTraded': True,
#       'formatDecimal': 2.95,
#       'formatAmerican': '195',
#       'status': 'ONGOING',
#       'trueOdds': 2.95},
#      {'id': 'abb9777d-3e68-3c83-8163-cf225ba9f494',
#       'name': 'Tie',
#       'isTraded': True,
#       'formatDecimal': 1.9,
#       'formatAmerican': '-111',
#       'status': 'ONGOING',
#       'trueOdds': 1.9009009},
#      {'id': '2181450c-5cc4-3e3c-9736-d3ac7d0e5e15',
#       'name': 'Bozovic A / Wong H Y C',
#       'isTraded': True,
#       'formatDecimal': 4.65,
#       'formatAmerican': '365',
#       'status': 'ONGOING',
#       'trueOdds': 4.65}]},
#    {'id': '140bfa01-b212-30bd-b792-a62732afce08',
#     'name': '2nd Set Game Spread ',
#     'type': 'game-handicap-in-set',
#     'parameters': ['0', '1.5', '2'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'HANDICAP_HOME', 'value': '0', 'type': 'DOUBLE'},
#      {'key': 'HANDICAP_AWAY', 'value': '1.5', 'type': 'DOUBLE'},
#      {'key': 'SECTION', 'value': '2', 'type': 'LONG'}],
#     'outcomes': [{'id': 'a1b5fb43-0cb5-3828-bc39-4b65b52d1932',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E -1.5',
#       'isTraded': True,
#       'formatDecimal': 1.93,
#       'formatAmerican': '-107',
#       'status': 'ONGOING',
#       'trueOdds': 1.934579439},
#      {'id': '6465d728-c94a-3d0a-ad39-cc873b76f03a',
#       'name': 'Bozovic A / Wong H Y C +1.5',
#       'isTraded': True,
#       'formatDecimal': 1.74,
#       'formatAmerican': '-135',
#       'status': 'ONGOING',
#       'trueOdds': 1.74074074}]},
#    {'id': 'e1d585f8-1f20-3833-9451-3a68b14a925f',
#     'name': '2nd Set 4th Game Winner',
#     'type': 'game-win',
#     'parameters': ['2', '4'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '4', 'type': 'LONG'}],
#     'outcomes': [{'id': 'd8f61de0-b966-3fd0-88a1-a1bf3b1dbd8e',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E',
#       'isTraded': True,
#       'formatDecimal': 1.5,
#       'formatAmerican': '-200',
#       'status': 'ONGOING',
#       'trueOdds': 1.5},
#      {'id': 'c29d7d86-1cc0-3248-ac66-65845ae725af',
#       'name': 'Bozovic A / Wong H Y C',
#       'isTraded': True,
#       'formatDecimal': 2.4,
#       'formatAmerican': '140',
#       'status': 'ONGOING',
#       'trueOdds': 2.4}]},
#    {'id': '0fd25a41-11c5-3410-b039-32fbedf8ebe7',
#     'name': 'Total Games',
#     'type': 'games-more-less-than',
#     'parameters': ['23.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'OVER_UNDER', 'value': '23.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '532b8b52-9564-3d0e-a646-9a16178a0dc1',
#       'name': 'Over 23.5',
#       'isTraded': True,
#       'formatDecimal': 2.45,
#       'formatAmerican': '145',
#       'status': 'ONGOING',
#       'trueOdds': 2.45},
#      {'id': '5de6b271-515e-3bbf-9cb3-11ba27125746',
#       'name': 'Under 23.5',
#       'isTraded': True,
#       'formatDecimal': 1.46,
#       'formatAmerican': '-213',
#       'status': 'ONGOING',
#       'trueOdds': 1.469483568}]},
#    {'id': '99b12118-f08c-345c-8a37-b31ee891dce9',
#     'name': 'Set Spread ',
#     'type': 'handicap',
#     'parameters': ['0', '1.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'HANDICAP_HOME', 'value': '0', 'type': 'DOUBLE'},
#      {'key': 'HANDICAP_AWAY', 'value': '1.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': 'ad66e758-36b6-3dc5-ba09-4d0385354161',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E -1.5',
#       'isTraded': True,
#       'formatDecimal': 1.74,
#       'formatAmerican': '-135',
#       'status': 'ONGOING',
#       'trueOdds': 1.74074074},
#      {'id': '564d5db3-d4c1-3061-a2a9-b0411c6973fb',
#       'name': 'Bozovic A / Wong H Y C +1.5',
#       'isTraded': True,
#       'formatDecimal': 1.93,
#       'formatAmerican': '-107',
#       'status': 'ONGOING',
#       'trueOdds': 1.934579439}]},
#    {'id': 'dca2c9d2-b8ea-30c7-8d29-4661e2af1a0a',
#     'name': 'Hinojosa Gomez J / Reasco Gonzalez M E To Win Exactly One Set',
#     'type': 'home-to-win-exactly-one-set',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'outcomes': [{'id': '0084a0ee-f13e-31a6-8bc3-251df9fc8377',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 3.0,
#       'formatAmerican': '200',
#       'status': 'ONGOING',
#       'trueOdds': 3.0},
#      {'id': 'e2e42c0c-2774-3f5b-aa27-ec587cacdb2e',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 1.32,
#       'formatAmerican': '-312',
#       'status': 'ONGOING',
#       'trueOdds': 1.32051282}]},
#    {'id': '764fa63b-4a30-3f44-a5c4-2c76e7ab5e10',
#     'name': 'Hinojosa Gomez J / Reasco Gonzalez M E To Win Exactly Two Sets',
#     'type': 'home-to-win-exactly-two-sets',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'outcomes': [{'id': 'a37eef8f-037e-31ab-8215-5d052223ff4a',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 1.32,
#       'formatAmerican': '-312',
#       'status': 'ONGOING',
#       'trueOdds': 1.32051282},
#      {'id': 'bcfe402d-a2dc-31b5-b546-b86db63e44f3',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 3.0,
#       'formatAmerican': '200',
#       'status': 'ONGOING',
#       'trueOdds': 3.0}]},
#    {'id': '9ed58885-ff4b-3eab-9609-607c39be13d8',
#     'name': '2nd Set 4th Game Winner + Score',
#     'type': 'other-games-score',
#     'parameters': ['2', '4'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '4', 'type': 'LONG'}],
#     'outcomes': [{'id': '7493cbc0-f50e-388e-a35e-6d12a9365932',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E Win to 0',
#       'isTraded': True,
#       'formatDecimal': 7.5,
#       'formatAmerican': '650',
#       'status': 'ONGOING',
#       'trueOdds': 7.5},
#      {'id': '54077ac1-830a-3fe2-9609-99a54cd0e632',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E Win to 15',
#       'isTraded': True,
#       'formatDecimal': 4.85,
#       'formatAmerican': '385',
#       'status': 'ONGOING',
#       'trueOdds': 4.85},
#      {'id': '3df5a101-44b2-32a9-9e5b-1aa525d08d37',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E Win  to 30',
#       'isTraded': True,
#       'formatDecimal': 4.45,
#       'formatAmerican': '345',
#       'status': 'ONGOING',
#       'trueOdds': 4.45},
#      {'id': '0f00ed7c-3b0e-35f0-9d6f-9940b031552d',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E Win to 40',
#       'isTraded': True,
#       'formatDecimal': 5.3,
#       'formatAmerican': '430',
#       'status': 'ONGOING',
#       'trueOdds': 5.3},
#      {'id': 'd2b61b2d-d999-32dd-9fde-d392687fad9e',
#       'name': 'Bozovic A / Wong H Y C Win to 0',
#       'isTraded': True,
#       'formatDecimal': 22.0,
#       'formatAmerican': '2100',
#       'status': 'ONGOING',
#       'trueOdds': 22.0},
#      {'id': 'b1bacbbd-b746-3eff-8be6-fb0beae0aecd',
#       'name': 'Bozovic A / Wong H Y C Win to 15',
#       'isTraded': True,
#       'formatDecimal': 9.75,
#       'formatAmerican': '875',
#       'status': 'ONGOING',
#       'trueOdds': 9.75},
#      {'id': 'be684bab-04de-3f72-a56a-0c7acf05e526',
#       'name': 'Bozovic A / Wong H Y C Win to 30',
#       'isTraded': True,
#       'formatDecimal': 7.0,
#       'formatAmerican': '600',
#       'status': 'ONGOING',
#       'trueOdds': 7.0},
#      {'id': 'f74e5c58-dca6-3157-8150-76f079d71b86',
#       'name': 'Bozovic A / Wong H Y C Win to 40',
#       'isTraded': True,
#       'formatDecimal': 6.25,
#       'formatAmerican': '525',
#       'status': 'ONGOING',
#       'trueOdds': 6.25}]},
#    {'id': '320ab57e-f52a-3834-b57c-95f1ec5bab89',
#     'name': 'Correct Set Score',
#     'type': 'point-bet-2sets',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'outcomes': [{'id': 'db2e1a5b-7c31-3735-9e0f-864cda4becf4',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E  2-0 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 1.69,
#       'formatAmerican': '-143',
#       'status': 'ONGOING',
#       'trueOdds': 1.699300699},
#      {'id': 'df90e266-7286-3730-afb4-44fd28d65c91',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 2-1 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 4.7,
#       'formatAmerican': '370',
#       'status': 'ONGOING',
#       'trueOdds': 4.7},
#      {'id': '5b0fa6b9-65cd-3683-9de1-2ed4cdb0a85a',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 1-2 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 3.0,
#       'formatAmerican': '200',
#       'status': 'ONGOING',
#       'trueOdds': 3.0}]},
#    {'id': '8865af10-5170-3d71-be89-48c243529e3b',
#     'name': 'Total Sets',
#     'type': 'points-more-less-than',
#     'parameters': ['2.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'OVER_UNDER', 'value': '2.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': 'f222f731-59e7-3707-bd03-929addc05cba',
#       'name': 'Over 2.5',
#       'isTraded': True,
#       'formatDecimal': 1.97,
#       'formatAmerican': '-103',
#       'status': 'ONGOING',
#       'trueOdds': 1.970873786},
#      {'id': '2394e166-ff8c-3446-9e41-3e593c26f54a',
#       'name': 'Under 2.5',
#       'isTraded': True,
#       'formatDecimal': 1.75,
#       'formatAmerican': '-133',
#       'status': 'ONGOING',
#       'trueOdds': 1.751879699}]},
#    {'id': 'b57003c2-71b9-336a-810e-5c0e78c1401d',
#     'name': '2nd Set Total Games',
#     'type': 'section-games-more-less',
#     'parameters': ['2', '9.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '9.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '8bdac7ae-ba45-3623-83fc-75f8520ca52a',
#       'name': 'Over 9.5',
#       'isTraded': True,
#       'formatDecimal': 1.68,
#       'formatAmerican': '-145',
#       'status': 'ONGOING',
#       'trueOdds': 1.689655172},
#      {'id': 'b4bd98c8-83a8-3667-b669-6c9f7980a2bf',
#       'name': 'Under 9.5',
#       'isTraded': True,
#       'formatDecimal': 1.97,
#       'formatAmerican': '-103',
#       'status': 'ONGOING',
#       'trueOdds': 1.970873786}]},
#    {'id': '6507fa1c-ada8-398c-b772-7f6302dc7ba5',
#     'name': '2nd Set Winner',
#     'type': 'section-win',
#     'parameters': ['2'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'}],
#     'outcomes': [{'id': '5c16b1ea-c606-3cce-b1dd-a1e5a66cf172',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E',
#       'isTraded': True,
#       'formatDecimal': 1.69,
#       'formatAmerican': '-143',
#       'status': 'ONGOING',
#       'trueOdds': 1.699300699},
#      {'id': '2107da79-227d-35a2-87ad-756910aadac4',
#       'name': 'Bozovic A / Wong H Y C',
#       'isTraded': True,
#       'formatDecimal': 1.95,
#       'formatAmerican': '-105',
#       'status': 'ONGOING',
#       'trueOdds': 1.952380952}]},
#    {'id': '058c4ff1-bcf4-3d22-9546-08cb49e62e06',
#     'name': 'Moneyline',
#     'type': 'standard',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'outcomes': [{'id': '183f5ae1-8c72-3fc6-b059-3140260dac04',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E',
#       'isTraded': True,
#       'formatDecimal': 1.32,
#       'formatAmerican': '-312',
#       'status': 'ONGOING',
#       'trueOdds': 1.32051282},
#      {'id': '9fa2acf2-6231-3170-aa8b-4a74b0d6a290',
#       'name': 'Bozovic A / Wong H Y C',
#       'isTraded': True,
#       'formatDecimal': 2.95,
#       'formatAmerican': '195',
#       'status': 'ONGOING',
#       'trueOdds': 2.95}]},
#    {'id': '7f77146f-7e56-3224-a99a-9b1a0fb98ad4',
#     'name': 'Match Winner & Total Games ',
#     'type': 'winner-and-total',
#     'parameters': ['23.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'OVER_UNDER', 'value': '23.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '2e27b9a2-dd0c-3670-b301-fad7646e3230',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E & Over 23.5',
#       'isTraded': True,
#       'formatDecimal': 4.0,
#       'formatAmerican': '300',
#       'status': 'ONGOING',
#       'trueOdds': 4.0},
#      {'id': 'e79e76af-e009-3c2b-bc3a-cc9d8167847c',
#       'name': 'Bozovic A / Wong H Y C & Over 23.5',
#       'isTraded': True,
#       'formatDecimal': 5.5,
#       'formatAmerican': '450',
#       'status': 'ONGOING',
#       'trueOdds': 5.5},
#      {'id': '2678284c-700b-313a-b118-612390376d49',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E & Under 23.5',
#       'isTraded': True,
#       'formatDecimal': 1.8,
#       'formatAmerican': '-125',
#       'status': 'ONGOING',
#       'trueOdds': 1.8},
#      {'id': '6ae356aa-13cc-378c-a64b-0dc48a5888df',
#       'name': 'Bozovic A / Wong H Y C & Under 23.5',
#       'isTraded': True,
#       'formatDecimal': 6.0,
#       'formatAmerican': '500',
#       'status': 'ONGOING',
#       'trueOdds': 6.0}]},
#    {'id': 'cb4506d4-2191-3bdf-975a-f92d19fa2933',
#     'name': '2nd Set Correct Score',
#     'type': 'xth-set-correct-score',
#     'parameters': ['2'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'}],
#     'outcomes': [{'id': 'df1dce5d-9643-3ffe-a2f0-9e8a2bad0d45',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E  6:1 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 22.0,
#       'formatAmerican': '2100',
#       'status': 'ONGOING',
#       'trueOdds': 22.0},
#      {'id': 'ae66ef4b-ba8b-3d00-9847-2d051530381d',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 6:2 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 7.0,
#       'formatAmerican': '600',
#       'status': 'ONGOING',
#       'trueOdds': 7.0},
#      {'id': '936229c5-d9a6-333d-b2ab-3ccbc314c00b',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 6:3 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 8.75,
#       'formatAmerican': '775',
#       'status': 'ONGOING',
#       'trueOdds': 8.75},
#      {'id': 'b21092ac-1ffd-327d-8845-f3530a89ecea',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 6:4 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 4.55,
#       'formatAmerican': '355',
#       'status': 'ONGOING',
#       'trueOdds': 4.55},
#      {'id': '07771fb8-aa3c-3a87-be54-bf84bfd20b9f',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 7:5 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 15.0,
#       'formatAmerican': '1400',
#       'status': 'ONGOING',
#       'trueOdds': 15.0},
#      {'id': 'c33aacab-3983-3d1c-9b3c-718714ab2def',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 7:6 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 12.5,
#       'formatAmerican': '1150',
#       'status': 'ONGOING',
#       'trueOdds': 12.5},
#      {'id': '0bf7a205-d5b4-3fd0-8e7d-97bde429face',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 1:6 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 30.0,
#       'formatAmerican': '2900',
#       'status': 'ONGOING',
#       'trueOdds': 30.0},
#      {'id': '8b1f869f-b22d-338e-967a-3e848ce6cec0',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 2:6 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 14.0,
#       'formatAmerican': '1300',
#       'status': 'ONGOING',
#       'trueOdds': 14.0},
#      {'id': '02d8280b-d9ac-33b2-9cf3-c078593e4c28',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 3:6 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 5.7,
#       'formatAmerican': '470',
#       'status': 'ONGOING',
#       'trueOdds': 5.7},
#      {'id': '8db66d1d-a9ee-3576-8c73-3703547a2687',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 4:6 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 7.75,
#       'formatAmerican': '675',
#       'status': 'ONGOING',
#       'trueOdds': 7.75},
#      {'id': 'c9c03d5e-da07-3d04-b8ee-8a0d0d1856fa',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 5:7 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 11.5,
#       'formatAmerican': '1050',
#       'status': 'ONGOING',
#       'trueOdds': 11.5},
#      {'id': 'dd598d58-bf89-363e-9fc8-600094fc79a8',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E 6:7 Bozovic A / Wong H Y C ',
#       'isTraded': True,
#       'formatDecimal': 10.0,
#       'formatAmerican': '900',
#       'status': 'ONGOING',
#       'trueOdds': 10.0}]},
#    {'id': 'd353fba0-b7af-3041-90d3-9ef0d2be5071',
#     'name': '2nd Set 4th Game Exact Points',
#     'type': 'xth-set-game-x-exact-points',
#     'parameters': ['2', '4'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '4', 'type': 'LONG'}],
#     'outcomes': [{'id': '7c063f45-9f28-3c39-8169-4b7be94836ad',
#       'name': '4 Points',
#       'isTraded': True,
#       'formatDecimal': 5.8,
#       'formatAmerican': '480',
#       'status': 'ONGOING',
#       'trueOdds': 5.8},
#      {'id': '3858d489-3691-3d4f-a8ac-1e2bed290aac',
#       'name': '5 Points',
#       'isTraded': True,
#       'formatDecimal': 3.4,
#       'formatAmerican': '240',
#       'status': 'ONGOING',
#       'trueOdds': 3.4},
#      {'id': '40accc1a-75f1-3621-89ab-ec08ebe4c131',
#       'name': '6 Points',
#       'isTraded': True,
#       'formatDecimal': 2.85,
#       'formatAmerican': '185',
#       'status': 'ONGOING',
#       'trueOdds': 2.85},
#      {'id': '23a2585a-dc66-32b3-83c1-fe6ab88949a6',
#       'name': '7+ Points',
#       'isTraded': True,
#       'formatDecimal': 3.05,
#       'formatAmerican': '205',
#       'status': 'ONGOING',
#       'trueOdds': 3.05}]},
#    {'id': '6919e616-de27-3580-8824-f98903697af2',
#     'name': '2nd Set 4 Game Race To 2nd Point',
#     'type': 'xth-set-game-x-race-to-x-points',
#     'parameters': ['2', '4', '2'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '4', 'type': 'LONG'},
#      {'key': 'POINT_NUMBER', 'value': '2', 'type': 'LONG'}],
#     'outcomes': [{'id': '29b142c3-5fa9-3f3e-9498-8b5b15dae34e',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E',
#       'isTraded': True,
#       'formatDecimal': 1.58,
#       'formatAmerican': '-170',
#       'status': 'ONGOING',
#       'trueOdds': 1.588235294},
#      {'id': 'a2ca9c79-fb76-3a97-98a0-d93575a4d70f',
#       'name': 'Bozovic A / Wong H Y C',
#       'isTraded': True,
#       'formatDecimal': 2.25,
#       'formatAmerican': '125',
#       'status': 'ONGOING',
#       'trueOdds': 2.25}]},
#    {'id': '62380b52-85ed-3274-b98d-4933188c7af0',
#     'name': '2nd Set Race To 3 Games',
#     'type': 'xth-set-race-to-x-games',
#     'parameters': ['2', '3'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'GAMES', 'value': '3', 'type': 'LONG'}],
#     'outcomes': [{'id': '10d82afa-c5a0-36a8-8235-d02c85d6191f',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E',
#       'isTraded': True,
#       'formatDecimal': 1.59,
#       'formatAmerican': '-167',
#       'status': 'ONGOING',
#       'trueOdds': 1.598802395},
#      {'id': '23200b38-2193-330a-915d-3ae917ca23ea',
#       'name': 'Bozovic A / Wong H Y C',
#       'isTraded': True,
#       'formatDecimal': 2.15,
#       'formatAmerican': '115',
#       'status': 'ONGOING',
#       'trueOdds': 2.15}]},
#    {'id': 'c5ec8304-82c2-3217-b4cd-a89a46f6fc03',
#     'name': '2nd Set Race To 4 Games',
#     'type': 'xth-set-race-to-x-games',
#     'parameters': ['2', '4'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'GAMES', 'value': '4', 'type': 'LONG'}],
#     'outcomes': [{'id': 'e05879b7-0a7a-3e33-9793-54be8891b769',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E',
#       'isTraded': True,
#       'formatDecimal': 1.69,
#       'formatAmerican': '-143',
#       'status': 'ONGOING',
#       'trueOdds': 1.699300699},
#      {'id': '6635de3e-e4ef-363b-bb23-a85131388899',
#       'name': 'Bozovic A / Wong H Y C',
#       'isTraded': True,
#       'formatDecimal': 1.95,
#       'formatAmerican': '-105',
#       'status': 'ONGOING',
#       'trueOdds': 1.952380952}]},
#    {'id': '8ad886e9-f509-3e64-a267-06a5eb5de53e',
#     'name': '2nd Set Race To 5 Games',
#     'type': 'xth-set-race-to-x-games',
#     'parameters': ['2', '5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'},
#      {'key': 'GAMES', 'value': '5', 'type': 'LONG'}],
#     'outcomes': [{'id': 'f77c53cf-bedf-3e02-aa31-f0688e99d43b',
#       'name': 'Hinojosa Gomez J / Reasco Gonzalez M E',
#       'isTraded': True,
#       'formatDecimal': 1.8,
#       'formatAmerican': '-125',
#       'status': 'ONGOING',
#       'trueOdds': 1.8},
#      {'id': '5c7b6d38-10aa-3df2-a9c3-4395435694af',
#       'name': 'Bozovic A / Wong H Y C',
#       'isTraded': True,
#       'formatDecimal': 1.9,
#       'formatAmerican': '-111',
#       'status': 'ONGOING',
#       'trueOdds': 1.9009009}]},
#    {'id': '88accb49-023e-3ad8-86b2-19b543244b8f',
#     'name': 'Will There Be A Tiebreak In The 2nd Set?',
#     'type': 'xth-set-will-there-be-a-tiebreak',
#     'parameters': ['2'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '2', 'type': 'LONG'}],
#     'outcomes': [{'id': '79e51963-0aab-350c-9c03-bf8b6a5908ea',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 5.2,
#       'formatAmerican': '420',
#       'status': 'ONGOING',
#       'trueOdds': 5.2},
#      {'id': 'b62879b5-f41a-3c18-90ce-5ac90fbc64e2',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 1.11,
#       'formatAmerican': '-900',
#       'status': 'ONGOING',
#       'trueOdds': 1.111111111}]}],
#   'eventType': 'MATCH',
#   'updatesCount': 146,
#   'displayInfo': {},
#   'score': {'total': {'home': {'sets': 1, 'games': 1, 'points': '30'},
#     'away': {'sets': 0, 'games': 1, 'points': '0'}},
#    'sections': [{'section': 1,
#      'home': {'sets': 1, 'games': 7, 'points': '0'},
#      'away': {'sets': 0, 'games': 6, 'points': '0'}},
#     {'section': 2,
#      'home': {'sets': 1, 'games': 1, 'points': '30'},
#      'away': {'sets': 0, 'games': 1, 'points': '0'}}]},
#   'gameClock': {'clockType': 'SECTIONS',
#    'eventState': 'RUNNING',
#    'sectionNumber': 2,
#    'techDisplayName': 'SET',
#    'activeParticipant': 'AWAY',
#    'firstServer': 'HOME'},
#   'eventReferences': [{'providerId': '90', 'eventId': '50352659'},
#    {'providerId': '102', 'eventId': '50352659'}],
#   'eventDetails': {'subgroupNameKey': 'ITF Dominican Republic 03A, Women Doubles, Final',
#    'best_of_sets': '3',
#    'block_cashout': 'false',
#    'activeParticipant': 'AWAY',
#    'tiebreak': 'immediate-tie-break',
#    'subgroupIdKey': '149621'},
#   'sportCurrentGameState': {'updatedAt': '0',
#    'netSportCurrentGameState': {'firstServer': 1,
#     'currentServer': 2,
#     'homeFullScore': 0,
#     'awayFullScore': 0}},
#   'lastModifiedTime': '2024-05-26T22:09:24.366Z',
#   'eventTags': ['awayParticipantStateLocation:UNKNOWN',
#    'venueStateLocation:OTHER',
#    'homeParticipantStateLocation:UNKNOWN',
#    'blockedOH',
#    'isTradedLive']},
#  {'id': 812878,
#   'startTime': '2024-05-26T17:50:00Z',
#   'messageTime': '2024-05-26T22:08:58.023Z',
#   'sportType': 'TENNIS',
#   'matchState': 'ONGOING',
#   'participants': [{'id': 557,
#     'name': 'Djere, Laslo',
#     'position': 'HOME',
#     'abbreviation': 'DJE'},
#    {'id': 579,
#     'name': 'Altmaier, Daniel',
#     'position': 'AWAY',
#     'abbreviation': 'ALT'}],
#   'status': 'RUNNING',
#   'marketCount': 23,
#   'group': {'id': 51,
#    'name': 'French Open Men',
#    'parentGroup': {'id': 18,
#     'name': 'ATP',
#     'parentGroup': {'id': 21, 'name': 'Tennis'}}},
#   'markets': [{'id': '5e59f74c-a2cc-377d-93a8-c047d9d96385',
#     'name': '5th Set 7th Game To Deuce',
#     'type': 'deuce-in-game',
#     'parameters': ['5', '7'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '5', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '7', 'type': 'LONG'}],
#     'outcomes': [{'id': 'b0f30c04-3040-3a71-8aec-0eb28bc8872f',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 3.15,
#       'formatAmerican': '215',
#       'status': 'ONGOING',
#       'trueOdds': 3.15},
#      {'id': 'e915776d-1e69-3f68-a25d-3afc696320ed',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 1.29,
#       'formatAmerican': '-340',
#       'status': 'ONGOING',
#       'trueOdds': 1.294117647}]},
#    {'id': '5b55d127-cd2a-36ee-8bab-2eab40a0488e',
#     'name': '5th Set 6th Game 2nd Point Winner',
#     'type': 'exact-game-point-in-set',
#     'parameters': ['5', '6', '2'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '5', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '6', 'type': 'LONG'},
#      {'key': 'POINT_NUMBER', 'value': '2', 'type': 'LONG'}],
#     'outcomes': [{'id': '757f7e0c-9d15-304a-8c82-801da2e3b6d7',
#       'name': 'Djere, Laslo',
#       'isTraded': True,
#       'formatDecimal': 1.46,
#       'formatAmerican': '-213',
#       'status': 'ONGOING',
#       'trueOdds': 1.469483568},
#      {'id': 'e8930028-2c9f-346a-ac70-96a69103a532',
#       'name': 'Altmaier, Daniel',
#       'isTraded': True,
#       'formatDecimal': 2.4,
#       'formatAmerican': '140',
#       'status': 'ONGOING',
#       'trueOdds': 2.4}]},
#    {'id': 'eb6b8ca1-edfe-3cd9-bcb6-f22482b56b2d',
#     'name': 'First 2 Points in 5th Set 7th Game',
#     'type': 'first-game-points-in-set',
#     'parameters': ['5', '7', '2'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '5', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '7', 'type': 'LONG'},
#      {'key': 'POINT_NUMBER', 'value': '2', 'type': 'LONG'}],
#     'outcomes': [{'id': '233c34d5-26e2-33fa-9d80-7c4e2c952ccd',
#       'name': 'Djere, Laslo',
#       'isTraded': True,
#       'formatDecimal': 5.2,
#       'formatAmerican': '420',
#       'status': 'ONGOING',
#       'trueOdds': 5.2},
#      {'id': '8ee598ed-22fe-3e0d-88c7-67371de20593',
#       'name': 'Tie',
#       'isTraded': True,
#       'formatDecimal': 1.95,
#       'formatAmerican': '-105',
#       'status': 'ONGOING',
#       'trueOdds': 1.952380952},
#      {'id': '44bc1b58-c59f-3a82-b6d3-1534eac4e000',
#       'name': 'Altmaier, Daniel',
#       'isTraded': True,
#       'formatDecimal': 2.7,
#       'formatAmerican': '170',
#       'status': 'ONGOING',
#       'trueOdds': 2.7}]},
#    {'id': '6a93e8e0-067f-330a-8bc4-38af63b5e2f9',
#     'name': 'Game Spread',
#     'type': 'game-handicap',
#     'parameters': ['0', '2.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'HANDICAP_HOME', 'value': '0', 'type': 'DOUBLE'},
#      {'key': 'HANDICAP_AWAY', 'value': '2.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '90471fe2-d013-3583-b456-8891cdb304f7',
#       'name': 'Djere, Laslo -2.5',
#       'isTraded': True,
#       'formatDecimal': 4.1,
#       'formatAmerican': '310',
#       'status': 'ONGOING',
#       'trueOdds': 4.1},
#      {'id': '931b8b0a-e454-3df6-80f8-b118985b1365',
#       'name': 'Altmaier, Daniel +2.5',
#       'isTraded': True,
#       'formatDecimal': 1.21,
#       'formatAmerican': '-475',
#       'status': 'ONGOING',
#       'trueOdds': 1.210526315}]},
#    {'id': 'f1ff8b4d-cce3-3140-b26d-8ebc06711c87',
#     'name': 'Game Spread',
#     'type': 'game-handicap',
#     'parameters': ['0', '1.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'HANDICAP_HOME', 'value': '0', 'type': 'DOUBLE'},
#      {'key': 'HANDICAP_AWAY', 'value': '1.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '931cfecf-370b-34d0-9693-09d7e2c7e02a',
#       'name': 'Djere, Laslo -1.5',
#       'isTraded': True,
#       'formatDecimal': 2.5,
#       'formatAmerican': '150',
#       'status': 'ONGOING',
#       'trueOdds': 2.5},
#      {'id': '4e84085a-e1cb-3b98-b951-65382a1af5f4',
#       'name': 'Altmaier, Daniel +1.5',
#       'isTraded': True,
#       'formatDecimal': 1.5,
#       'formatAmerican': '-200',
#       'status': 'ONGOING',
#       'trueOdds': 1.5}]},
#    {'id': '4f49daf5-82df-376e-a691-886073244e22',
#     'name': 'Game Spread',
#     'type': 'game-handicap',
#     'parameters': ['0', '0.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'HANDICAP_HOME', 'value': '0', 'type': 'DOUBLE'},
#      {'key': 'HANDICAP_AWAY', 'value': '0.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '806fb3f2-3037-33cb-a244-6493bf603cc8',
#       'name': 'Djere, Laslo -0.5',
#       'isTraded': True,
#       'formatDecimal': 1.26,
#       'formatAmerican': '-380',
#       'status': 'ONGOING',
#       'trueOdds': 1.263157894},
#      {'id': 'c539ed81-2272-3969-9ec0-88a887a6a308',
#       'name': 'Altmaier, Daniel +0.5',
#       'isTraded': True,
#       'formatDecimal': 3.6,
#       'formatAmerican': '260',
#       'status': 'ONGOING',
#       'trueOdds': 3.6}]},
#    {'id': '477c6a82-ecbe-310b-8f3d-847d9124908a',
#     'name': '5th Set 7th Game Winner',
#     'type': 'game-win',
#     'parameters': ['5', '7'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '5', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '7', 'type': 'LONG'}],
#     'outcomes': [{'id': 'fb6b1e74-d674-3587-a260-8ea644ba9343',
#       'name': 'Djere, Laslo',
#       'isTraded': True,
#       'formatDecimal': 2.9,
#       'formatAmerican': '190',
#       'status': 'ONGOING',
#       'trueOdds': 2.9},
#      {'id': 'ceb5c824-3e9e-3bc2-9946-36ef6052e184',
#       'name': 'Altmaier, Daniel',
#       'isTraded': True,
#       'formatDecimal': 1.34,
#       'formatAmerican': '-286',
#       'status': 'ONGOING',
#       'trueOdds': 1.349650349}]},
#    {'id': '29508d7c-ce3a-3de2-aa54-8de15a221498',
#     'name': 'Total Games',
#     'type': 'games-more-less-than',
#     'parameters': ['56.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'OVER_UNDER', 'value': '56.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '068e912e-5389-3955-9dee-56a409adc4ba',
#       'name': 'Over 56.5',
#       'isTraded': True,
#       'formatDecimal': 1.52,
#       'formatAmerican': '-192',
#       'status': 'ONGOING',
#       'trueOdds': 1.520833333},
#      {'id': '0adc4db8-f0b3-3233-a401-7cd47e85b183',
#       'name': 'Under 56.5',
#       'isTraded': True,
#       'formatDecimal': 2.3,
#       'formatAmerican': '130',
#       'status': 'ONGOING',
#       'trueOdds': 2.3}]},
#    {'id': '16d78f54-fc37-349d-9300-eadbe0b7c9b0',
#     'name': 'Total Games',
#     'type': 'games-more-less-than',
#     'parameters': ['57.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'OVER_UNDER', 'value': '57.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '8093afbb-83b8-34b3-aa5e-5388110e8d7a',
#       'name': 'Over 57.5',
#       'isTraded': True,
#       'formatDecimal': 3.6,
#       'formatAmerican': '260',
#       'status': 'ONGOING',
#       'trueOdds': 3.6},
#      {'id': '3049a32e-a4a1-3871-87f8-474aefad1f4c',
#       'name': 'Under 57.5',
#       'isTraded': True,
#       'formatDecimal': 1.21,
#       'formatAmerican': '-455',
#       'status': 'ONGOING',
#       'trueOdds': 1.219780219}]},
#    {'id': '6a2c3350-560b-3e38-be82-e416ba40c449',
#     'name': 'Total Games',
#     'type': 'games-more-less-than',
#     'parameters': ['58.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'OVER_UNDER', 'value': '58.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '4a40ecac-3b51-3a29-8f4c-d6b3243440cb',
#       'name': 'Over 58.5',
#       'isTraded': True,
#       'formatDecimal': 3.6,
#       'formatAmerican': '260',
#       'status': 'ONGOING',
#       'trueOdds': 3.6},
#      {'id': '6f244716-5bbf-3cf9-ae45-3ff4f3d3ea61',
#       'name': 'Under 58.5',
#       'isTraded': True,
#       'formatDecimal': 1.21,
#       'formatAmerican': '-455',
#       'status': 'ONGOING',
#       'trueOdds': 1.219780219}]},
#    {'id': 'e3281eed-3077-3adc-a387-037ff7ad4242',
#     'name': '5th Set 7th Game Winner + Score',
#     'type': 'other-games-score',
#     'parameters': ['5', '7'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '5', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '7', 'type': 'LONG'}],
#     'outcomes': [{'id': '5743a60e-7a0b-3d86-882e-4e29e431a5c4',
#       'name': 'Djere, Laslo Win to 0',
#       'isTraded': True,
#       'formatDecimal': 28.0,
#       'formatAmerican': '2700',
#       'status': 'ONGOING',
#       'trueOdds': 28.0},
#      {'id': 'b9d9c5f2-8cc1-3300-ae9d-403af29b7cc8',
#       'name': 'Djere, Laslo Win to 15',
#       'isTraded': True,
#       'formatDecimal': 12.0,
#       'formatAmerican': '1100',
#       'status': 'ONGOING',
#       'trueOdds': 12.0},
#      {'id': '0f7d303d-12c9-3298-9bdb-0e9eb4c17f62',
#       'name': 'Djere, Laslo Win  to 30',
#       'isTraded': True,
#       'formatDecimal': 8.25,
#       'formatAmerican': '725',
#       'status': 'ONGOING',
#       'trueOdds': 8.25},
#      {'id': 'ae6bab15-1117-3107-9e22-4d76c005dd3e',
#       'name': 'Djere, Laslo Win to 40',
#       'isTraded': True,
#       'formatDecimal': 8.75,
#       'formatAmerican': '775',
#       'status': 'ONGOING',
#       'trueOdds': 8.75},
#      {'id': '17aea5d6-f40d-38b6-be0b-2ead2bc80a77',
#       'name': 'Altmaier, Daniel Win to 0',
#       'isTraded': True,
#       'formatDecimal': 6.5,
#       'formatAmerican': '550',
#       'status': 'ONGOING',
#       'trueOdds': 6.5},
#      {'id': '19d41219-1cf1-3560-a7e0-7bf5fffe165d',
#       'name': 'Altmaier, Daniel Win to 15',
#       'isTraded': True,
#       'formatDecimal': 4.4,
#       'formatAmerican': '340',
#       'status': 'ONGOING',
#       'trueOdds': 4.4},
#      {'id': 'a54074d1-e3e1-3a1c-a85f-c95f7cf31027',
#       'name': 'Altmaier, Daniel Win to 30',
#       'isTraded': True,
#       'formatDecimal': 4.25,
#       'formatAmerican': '325',
#       'status': 'ONGOING',
#       'trueOdds': 4.25},
#      {'id': 'cc8518e5-d67e-3160-a2ea-fdb698a205ea',
#       'name': 'Altmaier, Daniel Win to 40',
#       'isTraded': True,
#       'formatDecimal': 4.8,
#       'formatAmerican': '380',
#       'status': 'ONGOING',
#       'trueOdds': 4.8}]},
#    {'id': '31a1ddee-e2dd-39ad-8be0-1c2d1b774fa8',
#     'name': 'Moneyline',
#     'type': 'standard',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'outcomes': [{'id': '91b9efee-81c2-360e-95b3-62273af5e20c',
#       'name': 'Djere, Laslo',
#       'isTraded': True,
#       'formatDecimal': 1.14,
#       'formatAmerican': '-714',
#       'status': 'ONGOING',
#       'trueOdds': 1.140056022},
#      {'id': '1319a312-4bfc-3ee2-809a-f889ff4afdc0',
#       'name': 'Altmaier, Daniel',
#       'isTraded': True,
#       'formatDecimal': 4.65,
#       'formatAmerican': '365',
#       'status': 'ONGOING',
#       'trueOdds': 4.65}]},
#    {'id': '83619db8-1ad1-3750-a3ce-c4e793d0edc9',
#     'name': 'Djere, Laslo Total Games',
#     'type': 'team-points-more-less',
#     'parameters': ['1', '27.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'TEAM', 'value': '1', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '27.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '8f68f679-c622-39af-8b8c-0c56caea6492',
#       'name': 'Over 27.5',
#       'isTraded': True,
#       'formatDecimal': 1.04,
#       'formatAmerican': '-2500',
#       'status': 'ONGOING',
#       'trueOdds': 1.04},
#      {'id': '7a17280c-ee0a-3cea-984e-bd07b5c7b584',
#       'name': 'Under 27.5',
#       'isTraded': True,
#       'formatDecimal': 9.25,
#       'formatAmerican': '825',
#       'status': 'ONGOING',
#       'trueOdds': 9.25}]},
#    {'id': '1f27655f-c133-3b52-9ee0-befefa4acad8',
#     'name': 'Djere, Laslo Total Games',
#     'type': 'team-points-more-less',
#     'parameters': ['1', '28.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'TEAM', 'value': '1', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '28.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '877b91d9-37e4-3c49-a118-aeddff6a6c9e',
#       'name': 'Over 28.5',
#       'isTraded': True,
#       'formatDecimal': 1.07,
#       'formatAmerican': '-1300',
#       'status': 'ONGOING',
#       'trueOdds': 1.076923076},
#      {'id': 'd72ee000-9c34-3edd-9b9b-ac37dceffa3f',
#       'name': 'Under 28.5',
#       'isTraded': True,
#       'formatDecimal': 7.25,
#       'formatAmerican': '625',
#       'status': 'ONGOING',
#       'trueOdds': 7.25}]},
#    {'id': '54381ee6-ab8b-32b1-b6be-2331b937d9d4',
#     'name': 'Djere, Laslo Total Games',
#     'type': 'team-points-more-less',
#     'parameters': ['1', '29.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'TEAM', 'value': '1', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '29.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '3b3f468c-b655-3901-ab46-f756ec152136',
#       'name': 'Over 29.5',
#       'isTraded': True,
#       'formatDecimal': 6.0,
#       'formatAmerican': '500',
#       'status': 'ONGOING',
#       'trueOdds': 6.0},
#      {'id': '31774f89-8bdd-33e1-88f0-725df8348a02',
#       'name': 'Under 29.5',
#       'isTraded': True,
#       'formatDecimal': 1.11,
#       'formatAmerican': '-900',
#       'status': 'ONGOING',
#       'trueOdds': 1.111111111}]},
#    {'id': '224da8fb-96c0-34dd-a439-6b89eb17e0f0',
#     'name': 'Altmaier, Daniel Total Games',
#     'type': 'team-points-more-less',
#     'parameters': ['2', '27.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': False,
#     'specifier': [{'key': 'TEAM', 'value': '2', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '27.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '870fbd47-3e47-3c24-bfa9-d212eb94768a',
#       'name': 'Over 27.5',
#       'isTraded': True,
#       'formatDecimal': 1.5,
#       'formatAmerican': '-200',
#       'status': 'ONGOING',
#       'trueOdds': 1.5},
#      {'id': '551b72c7-e447-381a-b48b-ed804963165b',
#       'name': 'Under 27.5',
#       'isTraded': True,
#       'formatDecimal': 2.5,
#       'formatAmerican': '150',
#       'status': 'ONGOING',
#       'trueOdds': 2.5}]},
#    {'id': '9e881b5b-4892-31ae-b6df-2991b3032e50',
#     'name': 'Altmaier, Daniel Total Games',
#     'type': 'team-points-more-less',
#     'parameters': ['2', '28.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'TEAM', 'value': '2', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '28.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': 'f82b5ceb-d59b-3b81-967e-833b5b8835ae',
#       'name': 'Over 28.5',
#       'isTraded': True,
#       'formatDecimal': 3.05,
#       'formatAmerican': '205',
#       'status': 'ONGOING',
#       'trueOdds': 3.05},
#      {'id': '8015890a-5611-3e54-ab95-940bb4bec52e',
#       'name': 'Under 28.5',
#       'isTraded': True,
#       'formatDecimal': 1.34,
#       'formatAmerican': '-290',
#       'status': 'ONGOING',
#       'trueOdds': 1.344827586}]},
#    {'id': '057be173-d463-3a05-8f99-ed931350ae95',
#     'name': 'Altmaier, Daniel Total Games',
#     'type': 'team-points-more-less',
#     'parameters': ['2', '29.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'TEAM', 'value': '2', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '29.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': 'f8a8a0b9-5fe4-355d-943b-7d199e17cc0b',
#       'name': 'Over 29.5',
#       'isTraded': True,
#       'formatDecimal': 3.6,
#       'formatAmerican': '260',
#       'status': 'ONGOING',
#       'trueOdds': 3.6},
#      {'id': '1d9bd328-7b02-31fb-8a58-480c11e60fc7',
#       'name': 'Under 29.5',
#       'isTraded': True,
#       'formatDecimal': 1.26,
#       'formatAmerican': '-380',
#       'status': 'ONGOING',
#       'trueOdds': 1.263157894}]},
#    {'id': 'ad3907c4-1980-3ba0-b670-45398a87c168',
#     'name': '5th Set Correct Score',
#     'type': 'xth-set-correct-score',
#     'parameters': ['5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '5', 'type': 'LONG'}],
#     'outcomes': [{'id': '195fc6c0-def5-309f-b21c-76234c748717',
#       'name': 'Djere, Laslo 6:2 Altmaier, Daniel ',
#       'isTraded': True,
#       'formatDecimal': 4.05,
#       'formatAmerican': '305',
#       'status': 'ONGOING',
#       'trueOdds': 4.05},
#      {'id': '02f15300-cdd3-3821-a312-b27b7ed25698',
#       'name': 'Djere, Laslo 6:3 Altmaier, Daniel ',
#       'isTraded': True,
#       'formatDecimal': 5.0,
#       'formatAmerican': '400',
#       'status': 'ONGOING',
#       'trueOdds': 5.0},
#      {'id': 'd34688f4-e086-32f9-a788-28aeb50d2b09',
#       'name': 'Djere, Laslo 6:4 Altmaier, Daniel ',
#       'isTraded': True,
#       'formatDecimal': 2.5,
#       'formatAmerican': '150',
#       'status': 'ONGOING',
#       'trueOdds': 2.5},
#      {'id': '6881ca60-3eb7-3b31-b8bf-8bd117a6f677',
#       'name': 'Djere, Laslo 7:5 Altmaier, Daniel ',
#       'isTraded': True,
#       'formatDecimal': 16.0,
#       'formatAmerican': '1500',
#       'status': 'ONGOING',
#       'trueOdds': 16.0},
#      {'id': 'bdc9d2be-3fc9-316b-8a99-24d295ef5344',
#       'name': 'Djere, Laslo 7:6 Altmaier, Daniel ',
#       'isTraded': True,
#       'formatDecimal': 10.0,
#       'formatAmerican': '900',
#       'status': 'ONGOING',
#       'trueOdds': 10.0},
#      {'id': '83a41fac-06a3-3def-be16-154abcd57bd9',
#       'name': 'Djere, Laslo 3:6 Altmaier, Daniel ',
#       'isTraded': True,
#       'formatDecimal': 32.0,
#       'formatAmerican': '3100',
#       'status': 'ONGOING',
#       'trueOdds': 32.0},
#      {'id': 'ca624681-0271-3fa8-b156-3730b33f9837',
#       'name': 'Djere, Laslo 4:6 Altmaier, Daniel ',
#       'isTraded': True,
#       'formatDecimal': 19.5,
#       'formatAmerican': '1850',
#       'status': 'ONGOING',
#       'trueOdds': 19.5},
#      {'id': 'ba19ddb1-92d8-3701-96c7-add4be5900f1',
#       'name': 'Djere, Laslo 5:7 Altmaier, Daniel ',
#       'isTraded': True,
#       'formatDecimal': 21.0,
#       'formatAmerican': '2000',
#       'status': 'ONGOING',
#       'trueOdds': 21.0},
#      {'id': 'a130518a-0cc4-3626-996e-9fe7d1bbf4cf',
#       'name': 'Djere, Laslo 6:7 Altmaier, Daniel ',
#       'isTraded': True,
#       'formatDecimal': 12.5,
#       'formatAmerican': '1150',
#       'status': 'ONGOING',
#       'trueOdds': 12.5}]},
#    {'id': 'b337a547-7a86-3579-bcb9-4b03129dc216',
#     'name': '5th Set 7th Game Exact Points',
#     'type': 'xth-set-game-x-exact-points',
#     'parameters': ['5', '7'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'SECTION', 'value': '5', 'type': 'LONG'},
#      {'key': 'SUBSECTION', 'value': '7', 'type': 'LONG'}],
#     'outcomes': [{'id': '8a870b22-4050-36bc-9b32-74827b80a0cf',
#       'name': '4 Points',
#       'isTraded': True,
#       'formatDecimal': 5.3,
#       'formatAmerican': '430',
#       'status': 'ONGOING',
#       'trueOdds': 5.3},
#      {'id': '373c07ba-c592-33f6-922b-d9d4c27c8a5c',
#       'name': '5 Points',
#       'isTraded': True,
#       'formatDecimal': 3.3,
#       'formatAmerican': '230',
#       'status': 'ONGOING',
#       'trueOdds': 3.3},
#      {'id': '5b83a499-cfaf-31b6-8971-3109cda263ce',
#       'name': '6 Points',
#       'isTraded': True,
#       'formatDecimal': 2.9,
#       'formatAmerican': '190',
#       'status': 'ONGOING',
#       'trueOdds': 2.9},
#      {'id': '394ab1d7-d57d-3089-8d54-5bc816e4cdd0',
#       'name': '7+ Points',
#       'isTraded': True,
#       'formatDecimal': 3.2,
# ...
#       'trueOdds': 5.4},
#      {'id': '91f38ebc-500e-3bb4-a303-0ba78a92238a',
#       'name': 'Chapecoense SC',
#       'isTraded': True,
#       'formatDecimal': 3.7,
#       'formatAmerican': '270',
#       'status': 'ONGOING',
#       'trueOdds': 3.7}]},
#    {'id': 'f8d8d49c-151d-37ff-abbd-02b5789c3526',
#     'name': '1st Half 2nd Goal',
#     'type': 'next-point-halftime',
#     'parameters': ['2'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': True,
#     'specifier': [{'key': 'POINT_NUMBER', 'value': '2', 'type': 'LONG'}],
#     'outcomes': [{'id': '4e9d5a9f-bc3c-3259-bc1a-e20827e5a6c4',
#       'name': 'Ceara SC CE',
#       'isTraded': True,
#       'formatDecimal': 4.8,
#       'formatAmerican': '380',
#       'status': 'ONGOING',
#       'trueOdds': 4.8},
#      {'id': '7c4bd712-de4a-3cc9-8835-03f299b02427',
#       'name': 'None',
#       'isTraded': True,
#       'formatDecimal': 1.21,
#       'formatAmerican': '-455',
#       'status': 'ONGOING',
#       'trueOdds': 1.219780219},
#      {'id': 'aea71e61-6d8a-357c-992a-f7dbc451a943',
#       'name': 'Chapecoense SC',
#       'isTraded': True,
#       'formatDecimal': 12.5,
#       'formatAmerican': '1150',
#       'status': 'ONGOING',
#       'trueOdds': 12.5}]},
#    {'id': '13d3dcc7-159e-3228-96d3-656a9a99410b',
#     'name': '1st Half Correct Score',
#     'type': 'point-bet-halftime',
#     'parameters': ['1'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': True,
#     'specifier': [{'key': 'SECTION', 'value': '1', 'type': 'LONG'}],
#     'outcomes': [{'id': 'e4a45f46-23a3-34db-8178-e8569f739f4c',
#       'name': '1-1',
#       'isTraded': True,
#       'formatDecimal': 4.1,
#       'formatAmerican': '310',
#       'status': 'ONGOING',
#       'trueOdds': 4.1},
#      {'id': '3a9c6b01-fa9d-3eec-b259-8e2389a74510',
#       'name': '2-2',
#       'isTraded': True,
#       'formatDecimal': 100.0,
#       'formatAmerican': '9900',
#       'status': 'ONGOING',
#       'trueOdds': 100.0},
#      {'id': 'a9ac142b-bf9f-3026-bde4-64c64df2a808',
#       'name': 'Ceara SC CE 2-1 Chapecoense SC',
#       'isTraded': True,
#       'formatDecimal': 40.0,
#       'formatAmerican': '3900',
#       'status': 'ONGOING',
#       'trueOdds': 40.0},
#      {'id': '3f74476c-8ed1-36ed-b28d-85b67987f00d',
#       'name': 'Ceara SC CE 0-1 Chapecoense SC',
#       'isTraded': True,
#       'formatDecimal': 1.16,
#       'formatAmerican': '-625',
#       'status': 'ONGOING',
#       'trueOdds': 1.16},
#      {'id': 'facb1b00-f330-37c6-a31e-dd612c79e197',
#       'name': 'Ceara SC CE 0-2 Chapecoense SC',
#       'isTraded': True,
#       'formatDecimal': 10.0,
#       'formatAmerican': '900',
#       'status': 'ONGOING',
#       'trueOdds': 10.0},
#      {'id': 'f51ff0ce-733b-3cbf-bb7d-d57ed092a2c0',
#       'name': 'Ceara SC CE 1-2 Chapecoense SC',
#       'isTraded': True,
#       'formatDecimal': 50.0,
#       'formatAmerican': '4900',
#       'status': 'ONGOING',
#       'trueOdds': 50.0},
#      {'id': 'b73d7c13-d11a-380a-a6ce-e975d423fbfe',
#       'name': 'Other',
#       'isTraded': True,
#       'formatDecimal': 100.0,
#       'formatAmerican': '9900',
#       'status': 'ONGOING',
#       'trueOdds': 100.0}]},
#    {'id': '90efaa86-697f-3329-950a-472c3d4e80fe',
#     'name': 'Total Goals',
#     'type': 'points-more-less-than',
#     'parameters': ['2.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': True,
#     'specifier': [{'key': 'OVER_UNDER', 'value': '2.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '354c95df-aafc-32d0-b28b-6d1f4ac1b296',
#       'name': 'Over 2.5',
#       'isTraded': True,
#       'formatDecimal': 1.75,
#       'formatAmerican': '-133',
#       'status': 'ONGOING',
#       'trueOdds': 1.751879699},
#      {'id': 'ae3d3bcc-cd59-3f6a-996f-af96e5bac226',
#       'name': 'Under 2.5',
#       'isTraded': True,
#       'formatDecimal': 2.0,
#       'formatAmerican': '100',
#       'status': 'ONGOING',
#       'trueOdds': 2.0}]},
#    {'id': '9ffedb52-8884-31cd-96da-d72ef3a89970',
#     'name': 'Both Teams To Score',
#     'type': 'score-both',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': True,
#     'outcomes': [{'id': 'f3a03c5f-1c2d-32d6-88b0-b4d090490953',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 1.3,
#       'formatAmerican': '-333',
#       'status': 'ONGOING',
#       'trueOdds': 1.3003003},
#      {'id': 'cc0a6ede-b1ec-36a4-b4f7-3d06fcd20024',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 3.3,
#       'formatAmerican': '230',
#       'status': 'ONGOING',
#       'trueOdds': 3.3}]},
#    {'id': 'ee604662-2c31-39f6-8abc-4960c76a8e9e',
#     'name': '1st Half Both Teams To Score',
#     'type': 'score-both-halftime',
#     'parameters': ['1'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': True,
#     'specifier': [{'key': 'SECTION', 'value': '1', 'type': 'LONG'}],
#     'outcomes': [{'id': '132045b2-aa41-3a6d-8f55-f4b6a58967d1',
#       'name': 'Yes',
#       'isTraded': True,
#       'formatDecimal': 4.6,
#       'formatAmerican': '360',
#       'status': 'ONGOING',
#       'trueOdds': 4.6},
#      {'id': '2d4444b3-1e1e-3722-afdb-511b8e8f47fe',
#       'name': 'No',
#       'isTraded': True,
#       'formatDecimal': 1.16,
#       'formatAmerican': '-625',
#       'status': 'ONGOING',
#       'trueOdds': 1.16}]},
#    {'id': 'c52cf3d2-7b0e-32a3-b451-3f8b32c0b3c9',
#     'name': '1st Half Total Goals',
#     'type': 'section-points-more-less',
#     'parameters': ['1', '1.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': True,
#     'specifier': [{'key': 'SECTION', 'value': '1', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '1.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '10f6ba7a-b0e7-3865-94c9-13b2741e37f5',
#       'name': 'Over 1.5',
#       'isTraded': True,
#       'formatDecimal': 3.7,
#       'formatAmerican': '270',
#       'status': 'ONGOING',
#       'trueOdds': 3.7},
#      {'id': 'ec2f140b-f351-3707-98c4-1fc481f88c9f',
#       'name': 'Under 1.5',
#       'isTraded': True,
#       'formatDecimal': 1.25,
#       'formatAmerican': '-400',
#       'status': 'ONGOING',
#       'trueOdds': 1.25}]},
#    {'id': '201c46a8-3811-3b87-9038-c9331f86804d',
#     'name': '1st Half Result',
#     'type': 'section-win',
#     'parameters': ['1'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': True,
#     'specifier': [{'key': 'SECTION', 'value': '1', 'type': 'LONG'}],
#     'outcomes': [{'id': '2b815c9b-f7c7-3d19-a3c6-0ccd25dd29ab',
#       'name': 'Ceara SC CE',
#       'isTraded': True,
#       'formatDecimal': 50.0,
#       'formatAmerican': '4900',
#       'status': 'ONGOING',
#       'trueOdds': 50.0},
#      {'id': 'a15c2b89-eac2-30f8-90f1-50fe2dd333e6',
#       'name': 'Tie',
#       'isTraded': True,
#       'formatDecimal': 5.2,
#       'formatAmerican': '420',
#       'status': 'ONGOING',
#       'trueOdds': 5.2},
#      {'id': '34d78895-f0f6-3809-ada1-e1d7b64f8b37',
#       'name': 'Chapecoense SC',
#       'isTraded': True,
#       'formatDecimal': 1.14,
#       'formatAmerican': '-714',
#       'status': 'ONGOING',
#       'trueOdds': 1.140056022}]},
#    {'id': 'e78a639e-2cd5-3d39-9c66-1addbbf14b78',
#     'name': 'Moneyline',
#     'type': 'standard',
#     'parameters': [],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': True,
#     'outcomes': [{'id': '435ceea8-4a35-3a3f-b2e8-f6af126a2043',
#       'name': 'Ceara SC CE',
#       'isTraded': True,
#       'formatDecimal': 3.5,
#       'formatAmerican': '250',
#       'status': 'ONGOING',
#       'trueOdds': 3.5},
#      {'id': 'c26ca0b2-0b1a-36cb-99c6-f440e8d397d5',
#       'name': 'Tie',
#       'isTraded': True,
#       'formatDecimal': 3.1,
#       'formatAmerican': '210',
#       'status': 'ONGOING',
#       'trueOdds': 3.1},
#      {'id': 'f44d0761-256d-39c0-9a52-b18bc5cbdd56',
#       'name': 'Chapecoense SC',
#       'isTraded': True,
#       'formatDecimal': 2.2,
#       'formatAmerican': '120',
#       'status': 'ONGOING',
#       'trueOdds': 2.2}]},
#    {'id': '2a05ae40-3a2c-3a07-a2d8-685115bc2cae',
#     'name': 'Ceara SC CE Total Goals',
#     'type': 'team-points-more-less',
#     'parameters': ['1', '0.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': True,
#     'specifier': [{'key': 'TEAM', 'value': '1', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '0.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': 'c50cadd8-f604-3956-b9e9-31e881006b14',
#       'name': 'Over 0.5',
#       'isTraded': True,
#       'formatDecimal': 1.3,
#       'formatAmerican': '-333',
#       'status': 'ONGOING',
#       'trueOdds': 1.3003003},
#      {'id': '3cb36c4e-7d10-37d3-9bc2-7e1a8b050af4',
#       'name': 'Under 0.5',
#       'isTraded': True,
#       'formatDecimal': 3.3,
#       'formatAmerican': '230',
#       'status': 'ONGOING',
#       'trueOdds': 3.3}]},
#    {'id': '83f4c83c-aac5-32d6-99a9-d6a6c149e6e8',
#     'name': 'Ceara SC CE Total Goals',
#     'type': 'team-points-more-less',
#     'parameters': ['1', '1.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': True,
#     'specifier': [{'key': 'TEAM', 'value': '1', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '1.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '6b35a13f-47bb-3928-8307-889341968c71',
#       'name': 'Over 1.5',
#       'isTraded': True,
#       'formatDecimal': 2.45,
#       'formatAmerican': '145',
#       'status': 'ONGOING',
#       'trueOdds': 2.45},
#      {'id': '2c9f09ed-2a07-3628-a58f-89ad7379902f',
#       'name': 'Under 1.5',
#       'isTraded': True,
#       'formatDecimal': 1.52,
#       'formatAmerican': '-192',
#       'status': 'ONGOING',
#       'trueOdds': 1.520833333}]},
#    {'id': '7be05396-2abd-35c0-81e9-ea587b9cf6f4',
#     'name': 'Chapecoense SC Total Goals',
#     'type': 'team-points-more-less',
#     'parameters': ['2', '1.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': True,
#     'specifier': [{'key': 'TEAM', 'value': '2', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '1.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '871c2e84-1bac-3c4d-8ab4-16657cad7414',
#       'name': 'Over 1.5',
#       'isTraded': True,
#       'formatDecimal': 2.3,
#       'formatAmerican': '130',
#       'status': 'ONGOING',
#       'trueOdds': 2.3},
#      {'id': 'affba4d4-4568-3603-8a1b-7da647d97d7e',
#       'name': 'Under 1.5',
#       'isTraded': True,
#       'formatDecimal': 1.57,
#       'formatAmerican': '-175',
#       'status': 'ONGOING',
#       'trueOdds': 1.571428571}]},
#    {'id': '4f561de8-3fa6-3c1a-80df-5ac787d0228a',
#     'name': 'Chapecoense SC Total Goals',
#     'type': 'team-points-more-less',
#     'parameters': ['2', '2.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': True,
#     'specifier': [{'key': 'TEAM', 'value': '2', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '2.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': 'a26b3515-e86b-3b66-b373-51c7fc2eae0b',
#       'name': 'Over 2.5',
#       'isTraded': True,
#       'formatDecimal': 7.5,
#       'formatAmerican': '650',
#       'status': 'ONGOING',
#       'trueOdds': 7.5},
#      {'id': '84d82c11-717b-3e90-835c-d8bc6402b653',
#       'name': 'Under 2.5',
#       'isTraded': True,
#       'formatDecimal': 1.06,
#       'formatAmerican': '-1429',
#       'status': 'ONGOING',
#       'trueOdds': 1.069979006}]},
#    {'id': '7543eb20-b4fe-30ef-9c55-a0aa76801739',
#     'name': '1st Half Ceara SC CE Total Goals',
#     'type': 'team-points-more-less-halftime',
#     'parameters': ['1', '0.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': True,
#     'specifier': [{'key': 'TEAM', 'value': '1', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '0.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': 'b63e8d91-6429-371c-b894-a11aeabac23f',
#       'name': 'Over 0.5',
#       'isTraded': True,
#       'formatDecimal': 4.6,
#       'formatAmerican': '360',
#       'status': 'ONGOING',
#       'trueOdds': 4.6},
#      {'id': 'ec047744-7713-3703-9350-de293fc67f58',
#       'name': 'Under 0.5',
#       'isTraded': True,
#       'formatDecimal': 1.16,
#       'formatAmerican': '-625',
#       'status': 'ONGOING',
#       'trueOdds': 1.16}]},
#    {'id': '7e9405c2-0bf8-3821-b9be-bc6ec4218559',
#     'name': '1st Half Chapecoense SC Total Goals',
#     'type': 'team-points-more-less-halftime',
#     'parameters': ['2', '1.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': True,
#     'sgpEligable': True,
#     'specifier': [{'key': 'TEAM', 'value': '2', 'type': 'LONG'},
#      {'key': 'OVER_UNDER', 'value': '1.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': '00d64c6f-695e-320f-8c0f-6a6e2067ed14',
#       'name': 'Over 1.5',
#       'isTraded': True,
#       'formatDecimal': 8.25,
#       'formatAmerican': '725',
#       'status': 'ONGOING',
#       'trueOdds': 8.25},
#      {'id': '358619db-47a4-307c-8c29-636b7bfaf844',
#       'name': 'Under 1.5',
#       'isTraded': True,
#       'formatDecimal': 1.04,
#       'formatAmerican': '-2500',
#       'status': 'ONGOING',
#       'trueOdds': 1.04}]},
#    {'id': '8fe9ca94-51a5-3919-91a3-2c328640a965',
#     'name': 'Moneyline & Total Goals',
#     'type': 'totals-team-wins',
#     'parameters': ['2.5'],
#     'status': 'OPEN',
#     'mostBalancedLine': False,
#     'sgpEligable': False,
#     'specifier': [{'key': 'OVER_UNDER', 'value': '2.5', 'type': 'DOUBLE'}],
#     'outcomes': [{'id': 'f86617a7-0809-301b-89ea-2a0cae59209e',
#       'name': ' Ceara SC CE & Over 2.5',
#       'isTraded': True,
#       'formatDecimal': 3.35,
#       'formatAmerican': '235',
#       'status': 'ONGOING',
#       'trueOdds': 3.35},
#      {'id': '7615317e-6a00-3af7-9fb0-058318609b5f',
#       'name': 'Tie & Over 2.5',
#       'isTraded': True,
#       'formatDecimal': 10.5,
#       'formatAmerican': '950',
#       'status': 'ONGOING',
#       'trueOdds': 10.5},
#      {'id': 'd5e35bf6-c5f5-3fb9-9bab-69fbcd0d1bd1',
#       'name': 'Tie & Under 2.5',
#       'isTraded': True,
#       'formatDecimal': 4.0,
#       'formatAmerican': '300',
#       'status': 'ONGOING',
#       'trueOdds': 4.0},
#      {'id': 'a275bfd6-9550-3093-ab66-ec850dca5596',
#       'name': 'Chapecoense SC & Over 2.5',
#       'isTraded': True,
#       'formatDecimal': 4.7,
#       'formatAmerican': '370',
#       'status': 'ONGOING',
#       'trueOdds': 4.7},
#      {'id': 'c4317e45-3896-3bd8-bca1-967fc4d3cd15',
#       'name': 'Chapecoense SC & Under 2.5',
#       'isTraded': True,
#       'formatDecimal': 3.65,
#       'formatAmerican': '265',
#       'status': 'ONGOING',
#       'trueOdds': 3.65}]}],
#   'eventType': 'MATCH',
#   'updatesCount': 184,
#   'displayInfo': {'displayTags': ['sgp-pre', 'sgp-live']},
#   'score': {'total': {'home': {'value': 0}, 'away': {'value': 1}},
#    'sections': [{'section': 1, 'home': {'value': 0}, 'away': {'value': 1}}]},
#   'aggregatedEventPoints': {'total': {'home': {'CORNER': 1,
#      'YELLOW_CARD': 0,
#      'RED_CARD': 0},
#     'away': {'CORNER': 0, 'YELLOW_CARD': 1, 'RED_CARD': 0}},
#    'sections': [{'section': 1,
#      'home': {'CORNER': 1, 'YELLOW_CARD': 0, 'RED_CARD': 0},
#      'away': {'CORNER': 0, 'YELLOW_CARD': 1, 'RED_CARD': 0}}]},
#   'gameClock': {'clockType': 'STOPWATCH',
#    'eventState': 'RUNNING',
#    'sectionType': 'REGULAR',
#    'sectionNumber': 1,
#    'sectionDuration': 2700,
#    'utcTimestamp': 1716759020234,
#    'sectionTime': 0,
#    'eventTime': 0,
#    'hasAdditionalTimeInSection': True,
#    'displayEventTime': True,
#    'regularSectionCount': 2,
#    'techDisplayName': 'HALF'},
#   'eventReferences': [{'providerId': '81', 'eventId': '53161862063419392'},
#    {'providerId': '84', 'eventId': '53161862063419392'},
#    {'providerId': '90', 'eventId': '48423849'},
#    {'providerId': '92', 'eventId': '48423849'},
#    {'providerId': '102', 'eventId': '48423849'},
#    {'providerId': '103', 'eventId': '53161862063419392'},
#    {'providerId': '104', 'eventId': '53161862063419392'},
#    {'providerId': '106', 'eventId': '53161862063419392'},
#    {'providerId': '107', 'eventId': '53161862063419392'}],
#   'eventDetails': {'subgroupNameKey': 'Brasileiro Serie B, Regular season',
#    'block_cashout': 'false',
#    'subgroupIdKey': '1449'},
#   'lastModifiedTime': '2024-05-26T22:09:25.038Z',
#   'eventTags': ['sgp-pre',
#    'awayParticipantStateLocation:OTHER',
#    'venueStateLocation:OTHER',
#    'sgp-live',
#    'homeParticipantStateLocation:OTHER',
#    'blockedOH',
#    'isTradedLive']}]

# %%
df = pd.DataFrame(data)

# %%
df["participants"]
# Out:
# 0     [{'id': 85914, 'name': 'Hinojosa Gomez J / Rea...
# 1     [{'id': 557, 'name': 'Djere, Laslo', 'position...
# 2     [{'id': 204, 'name': 'White Sox', 'position': ...
# 3     [{'id': 1099, 'name': 'Panthers', 'position': ...
# 4     [{'id': 55190, 'name': 'San Jose State', 'posi...
# 5     [{'id': 228, 'name': 'Angels', 'position': 'HO...
# 6     [{'id': 24, 'name': 'Athletics', 'position': '...
# 7     [{'id': 85773, 'name': 'Padres', 'position': '...
# 8     [{'id': 256, 'name': 'Diamondbacks', 'position...
# 9     [{'id': 9402, 'name': 'CA Sarmiento', 'positio...
# 10    [{'id': 35333, 'name': 'Racing de Cordoba', 'p...
# 11    [{'id': 36889, 'name': 'CD El Nacional', 'posi...
# 12    [{'id': 31731, 'name': 'Deportivo Maldonado', ...
# 13    [{'id': 2713, 'name': 'Gimnasia Y Esgrima La P...
# 14    [{'id': 2958, 'name': 'Kirchheimer, Strong', '...
# 15    [{'id': 2903, 'name': 'Langmo, Christian', 'po...
# 16    [{'id': 4853, 'name': 'Universidad de Chile', ...
# 17    [{'id': 1171, 'name': 'Ceara SC CE', 'position...
# Name: participants, dtype: object

# %%
participants_df = df['participants'].apply(pd.Series)

# %%
participants_eachone_df = participants_df[0].apply(pd.Series)

# %%
participants_eachone_df['match_id'] = df['id']

# %%
participants_eachone_df
# Out:
#        id                                    name position abbreviation  \
# 0   85914  Hinojosa Gomez J / Reasco Gonzalez M E     HOME          HRE
# 1     557                            Djere, Laslo     HOME          DJE
# 2     204                               White Sox     HOME          CWS
# 3    1099                                Panthers     HOME          FLA
# 4   55190                          San Jose State     HOME          SAN
# 5     228                                  Angels     HOME          LAA
# 6      24                               Athletics     HOME          OAK
# 7   85773                                  Padres     HOME           SD
# 8     256                            Diamondbacks     HOME          ARI
# 9    9402                            CA Sarmiento     HOME          CAS
# 10  35333                       Racing de Cordoba     HOME          RAC
# 11  36889                          CD El Nacional     HOME          ELN
# 12  31731                     Deportivo Maldonado     HOME          MAL
# 13   2713             Gimnasia Y Esgrima La Plata     HOME          GLP
# 14   2958                     Kirchheimer, Strong     HOME          KIR
# 15   2903                       Langmo, Christian     HOME          LAN
# 16   4853                    Universidad de Chile     HOME          UCH
# 17   1171                             Ceara SC CE     HOME          CEA
#
#     match_id
# 0     815139
# 1     812878
# 2     814260
# 3     807148
# 4     814658
# 5     814281
# 6     814282
# 7     814280
# 8     814296
# 9     809278
# 10    809872
# 11    811400
# 12    809579
# 13    808810
# 14    814471
# 15    814472
# 16    809021
# 17    809052

# %%
participants_df
# Out:
#                                                     0  \
# 0   {'id': 85914, 'name': 'Hinojosa Gomez J / Reas...
# 1   {'id': 557, 'name': 'Djere, Laslo', 'position'...
# 2   {'id': 204, 'name': 'White Sox', 'position': '...
# 3   {'id': 1099, 'name': 'Panthers', 'position': '...
# 4   {'id': 55190, 'name': 'San Jose State', 'posit...
# 5   {'id': 228, 'name': 'Angels', 'position': 'HOM...
# 6   {'id': 24, 'name': 'Athletics', 'position': 'H...
# 7   {'id': 85773, 'name': 'Padres', 'position': 'H...
# 8   {'id': 256, 'name': 'Diamondbacks', 'position'...
# 9   {'id': 9402, 'name': 'CA Sarmiento', 'position...
# 10  {'id': 35333, 'name': 'Racing de Cordoba', 'po...
# 11  {'id': 36889, 'name': 'CD El Nacional', 'posit...
# 12  {'id': 31731, 'name': 'Deportivo Maldonado', '...
# 13  {'id': 2713, 'name': 'Gimnasia Y Esgrima La Pl...
# 14  {'id': 2958, 'name': 'Kirchheimer, Strong', 'p...
# 15  {'id': 2903, 'name': 'Langmo, Christian', 'pos...
# 16  {'id': 4853, 'name': 'Universidad de Chile', '...
# 17  {'id': 1171, 'name': 'Ceara SC CE', 'position'...
#
#                                                     1
# 0   {'id': 85913, 'name': 'Bozovic A / Wong H Y C'...
# 1   {'id': 579, 'name': 'Altmaier, Daniel', 'posit...
# 2   {'id': 214, 'name': 'Orioles', 'position': 'AW...
# 3   {'id': 1105, 'name': 'Rangers', 'position': 'A...
# 4   {'id': 55049, 'name': 'Fresno State ', 'positi...
# 5   {'id': 206, 'name': 'Guardians', 'position': '...
# 6   {'id': 26, 'name': 'Astros', 'position': 'AWAY...
# 7   {'id': 17350, 'name': 'Yankees', 'position': '...
# 8   {'id': 241, 'name': 'Marlins', 'position': 'AW...
# 9   {'id': 31762, 'name': 'Independiente Rivadavia...
# 10  {'id': 10293, 'name': 'San Martin de Tucuman',...
# 11  {'id': 34634, 'name': 'Mushuc Runa SC', 'posit...
# 12  {'id': 32042, 'name': 'Atletico Fenix Montevid...
# 13  {'id': 2724, 'name': 'CA Banfield', 'position'...
# 14  {'id': 16039, 'name': 'Nefve, Axel', 'position...
# 15  {'id': 39396, 'name': 'Kumar, Pranav', 'positi...
# 16  {'id': 20598, 'name': 'Nublense', 'position': ...
# 17  {'id': 14, 'name': 'Chapecoense SC', 'position...

# %%
df
# Out:
#         id             startTime               messageTime   sportType  \
# 0   815139  2024-05-26T14:00:00Z  2024-05-26T22:09:24.236Z      TENNIS
# 1   812878  2024-05-26T17:50:00Z  2024-05-26T22:08:58.023Z      TENNIS
# 2   814260  2024-05-26T18:10:00Z  2024-05-26T22:09:38.382Z    BASEBALL
# 3   807148  2024-05-26T19:00:00Z  2024-05-26T22:09:05.952Z  ICE_HOCKEY
# 4   814658  2024-05-26T20:00:00Z  2024-05-26T22:06:47.722Z    BASEBALL
# 5   814281  2024-05-26T20:07:00Z  2024-05-26T22:08:43.213Z    BASEBALL
# 6   814282  2024-05-26T20:07:00Z  2024-05-26T22:09:32.182Z    BASEBALL
# 7   814280  2024-05-26T20:10:00Z  2024-05-26T22:09:35.569Z    BASEBALL
# 8   814296  2024-05-26T20:10:00Z  2024-05-26T22:09:38.140Z    BASEBALL
# 9   809278  2024-05-26T20:30:00Z  2024-05-26T22:09:27.465Z    FOOTBALL
# 10  809872  2024-05-26T20:30:00Z  2024-05-26T22:09:16.890Z    FOOTBALL
# 11  811400  2024-05-26T20:30:00Z  2024-05-26T22:09:15.346Z    FOOTBALL
# 12  809579  2024-05-26T20:30:00Z  2024-05-26T22:09:28.687Z    FOOTBALL
# 13  808810  2024-05-26T20:45:00Z  2024-05-26T22:09:14.998Z    FOOTBALL
# 14  814471  2024-05-26T20:50:00Z  2024-05-26T22:09:32.709Z      TENNIS
# 15  814472  2024-05-26T21:05:00Z  2024-05-26T22:09:26.035Z      TENNIS
# 16  809021  2024-05-26T21:30:00Z  2024-05-26T22:09:23.966Z    FOOTBALL
# 17  809052  2024-05-26T21:30:00Z  2024-05-26T22:09:24.902Z    FOOTBALL
#
#    matchState                                       participants   status  \
# 0     ONGOING  [{'id': 85914, 'name': 'Hinojosa Gomez J / Rea...  RUNNING
# 1     ONGOING  [{'id': 557, 'name': 'Djere, Laslo', 'position...  RUNNING
# 2     ONGOING  [{'id': 204, 'name': 'White Sox', 'position': ...  RUNNING
# 3     ONGOING  [{'id': 1099, 'name': 'Panthers', 'position': ...  RUNNING
# 4     ONGOING  [{'id': 55190, 'name': 'San Jose State', 'posi...  RUNNING
# 5     ONGOING  [{'id': 228, 'name': 'Angels', 'position': 'HO...  RUNNING
# 6     ONGOING  [{'id': 24, 'name': 'Athletics', 'position': '...  RUNNING
# 7     ONGOING  [{'id': 85773, 'name': 'Padres', 'position': '...  RUNNING
# 8     ONGOING  [{'id': 256, 'name': 'Diamondbacks', 'position...  RUNNING
# 9     ONGOING  [{'id': 9402, 'name': 'CA Sarmiento', 'positio...  RUNNING
# 10    ONGOING  [{'id': 35333, 'name': 'Racing de Cordoba', 'p...  RUNNING
# 11    ONGOING  [{'id': 36889, 'name': 'CD El Nacional', 'posi...  RUNNING
# 12    ONGOING  [{'id': 31731, 'name': 'Deportivo Maldonado', ...  RUNNING
# 13    ONGOING  [{'id': 2713, 'name': 'Gimnasia Y Esgrima La P...  RUNNING
# 14    ONGOING  [{'id': 2958, 'name': 'Kirchheimer, Strong', '...  RUNNING
# 15    ONGOING  [{'id': 2903, 'name': 'Langmo, Christian', 'po...  RUNNING
# 16    ONGOING  [{'id': 4853, 'name': 'Universidad de Chile', ...  RUNNING
# 17    ONGOING  [{'id': 1171, 'name': 'Ceara SC CE', 'position...  RUNNING
#
#     marketCount                                              group  \
# 0            25  {'id': 3434, 'name': 'ITF Dominican Republic 0...
# 1            23  {'id': 51, 'name': 'French Open Men', 'parentG...
# 2             3  {'id': 30, 'name': 'MLB', 'parentGroup': {'id'...
# 3             1  {'id': 81, 'name': 'NHL', 'parentGroup': {'id'...
# 4             1  {'id': 3995, 'name': 'NCAABB', 'parentGroup': ...
# 5            78  {'id': 30, 'name': 'MLB', 'parentGroup': {'id'...
# 6            50  {'id': 30, 'name': 'MLB', 'parentGroup': {'id'...
# 7            76  {'id': 30, 'name': 'MLB', 'parentGroup': {'id'...
# 8            80  {'id': 30, 'name': 'MLB', 'parentGroup': {'id'...
# 9            17  {'id': 1781, 'name': 'Argentina - Liga Profesi...
# 10            4  {'id': 3686, 'name': 'Argentina - Primera Naci...
# 11           13  {'id': 3962, 'name': 'Ecuador - LigaPro Primer...
# 12           13  {'id': 3677, 'name': 'Uruguay - Primera Divisi...
# 13           21  {'id': 1781, 'name': 'Argentina - Liga Profesi...
# 14           14  {'id': 1549, 'name': 'ATP Challenger Little Ro...
# 15           13  {'id': 1549, 'name': 'ATP Challenger Little Ro...
# 16            8  {'id': 2314, 'name': 'Chile - Primera Division...
# 17           32  {'id': 29, 'name': 'Brazil - Brasileiro Serie ...
#
#                                               markets  ...  \
# 0   [{'id': '759e6bee-19c9-3f0e-a4d4-0cb8d121eaab'...  ...
# 1   [{'id': '5e59f74c-a2cc-377d-93a8-c047d9d96385'...  ...
# 2   [{'id': '4deba7ae-426d-38b5-865c-a18597fcd38c'...  ...
# 3   [{'id': '80c49585-2edc-327d-81a3-14188cc867a4'...  ...
# 4   [{'id': '5468720f-ca9e-34eb-8774-86e1522ec2cc'...  ...
# 5   [{'id': 'f46f32ec-3b9b-3176-85b1-dcd231f95d91'...  ...
# 6   [{'id': '274ef578-0b81-3a10-b768-5eb84a0369cf'...  ...
# 7   [{'id': '30730fe3-edbf-388e-898a-3bb396680199'...  ...
# 8   [{'id': '7515045f-2524-3b6d-b009-c30e268abfa5'...  ...
# 9   [{'id': '2e8b6954-2071-338d-bd40-381a7852bc13'...  ...
# 10  [{'id': '38616b4e-019e-3e46-8193-66d011cf3da8'...  ...
# 11  [{'id': '8fbdd379-e14a-33df-bc8e-815a1218c76a'...  ...
# 12  [{'id': 'e25abef7-e47d-32db-bce1-dcb43fac1a7d'...  ...
# 13  [{'id': 'a7f0c43f-90f1-38bc-84d4-6a885565a928'...  ...
# 14  [{'id': '3703ef72-5ab2-35f6-a7f4-761e94040012'...  ...
# 15  [{'id': 'd6b5b3f0-2efc-35d1-8321-bbf759cd7b92'...  ...
# 16  [{'id': '589fc7dd-1249-32b2-b35c-6446e2418dfc'...  ...
# 17  [{'id': '616b2f60-524c-3c61-9b86-3d6fdd29ba40'...  ...
#
#                                  displayInfo  \
# 0                                         {}
# 1                                         {}
# 2                                         {}
# 3                                         {}
# 4               {'displayTags': ['sgp-pre']}
# 5                                         {}
# 6                                         {}
# 7                                         {}
# 8                                         {}
# 9   {'displayTags': ['sgp-pre', 'sgp-live']}
# 10  {'displayTags': ['sgp-pre', 'sgp-live']}
# 11  {'displayTags': ['sgp-pre', 'sgp-live']}
# 12  {'displayTags': ['sgp-pre', 'sgp-live']}
# 13  {'displayTags': ['sgp-pre', 'sgp-live']}
# 14                                        {}
# 15                                        {}
# 16  {'displayTags': ['sgp-pre', 'sgp-live']}
# 17  {'displayTags': ['sgp-pre', 'sgp-live']}
#
#                                                 score  \
# 0   {'total': {'home': {'sets': 1, 'games': 1, 'po...
# 1   {'total': {'home': {'sets': 2, 'games': 3, 'po...
# 2   {'total': {'home': {'value': 1}, 'away': {'val...
# 3   {'total': {'home': {'value': 4}, 'away': {'val...
# 4   {'total': {'home': {'value': 3}, 'away': {'val...
# 5   {'total': {'home': {'value': 2}, 'away': {'val...
# 6   {'total': {'home': {'value': 1}, 'away': {'val...
# 7   {'total': {'home': {'value': 3}, 'away': {'val...
# 8   {'total': {'home': {'value': 0}, 'away': {'val...
# 9   {'total': {'home': {'value': 0}, 'away': {'val...
# 10  {'total': {'home': {'value': 0}, 'away': {'val...
# 11  {'total': {'home': {'value': 1}, 'away': {'val...
# 12  {'total': {'home': {'value': 0}, 'away': {'val...
# 13  {'total': {'home': {'value': 0}, 'away': {'val...
# 14  {'total': {'home': {'sets': 0, 'games': 2, 'po...
# 15  {'total': {'home': {'sets': 0, 'games': 1, 'po...
# 16  {'total': {'home': {'value': 0}, 'away': {'val...
# 17  {'total': {'home': {'value': 0}, 'away': {'val...
#
#                                             gameClock  \
# 0   {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 1   {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 2   {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 3   {'clockType': 'TIMER', 'eventState': 'BREAK', ...
# 4   {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 5   {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 6   {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 7   {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 8   {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 9   {'clockType': 'STOPWATCH', 'eventState': 'RUNN...
# 10  {'clockType': 'STOPWATCH', 'eventState': 'RUNN...
# 11  {'clockType': 'STOPWATCH', 'eventState': 'RUNN...
# 12  {'clockType': 'STOPWATCH', 'eventState': 'RUNN...
# 13  {'clockType': 'STOPWATCH', 'eventState': 'RUNN...
# 14  {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 15  {'clockType': 'SECTIONS', 'eventState': 'RUNNI...
# 16  {'clockType': 'STOPWATCH', 'eventState': 'RUNN...
# 17  {'clockType': 'STOPWATCH', 'eventState': 'RUNN...
#
#                                       eventReferences  \
# 0   [{'providerId': '90', 'eventId': '50352659'}, ...
# 1   [{'providerId': '81', 'eventId': '535209659452...
# 2   [{'providerId': '49', 'eventId': '23045'}, {'p...
# 3   [{'providerId': '49', 'eventId': '23016'}, {'p...
# 4   [{'providerId': '84', 'eventId': '537495075733...
# 5   [{'providerId': '81', 'eventId': '536985841216...
# 6   [{'providerId': '81', 'eventId': '536984893482...
# 7   [{'providerId': '81', 'eventId': '536985842024...
# 8   [{'providerId': '81', 'eventId': '536998876977...
# 9   [{'providerId': '81', 'eventId': '529965919598...
# 10  [{'providerId': '81', 'eventId': '532662777725...
# 11  [{'providerId': '81', 'eventId': '531715985298...
# 12  [{'providerId': '81', 'eventId': '531546212183...
# 13  [{'providerId': '81', 'eventId': '529969351147...
# 14  [{'providerId': '71', 'eventId': '11083654'}, ...
# 15  [{'providerId': '71', 'eventId': '11083656'}, ...
# 16  [{'providerId': '81', 'eventId': '531611963927...
# 17  [{'providerId': '81', 'eventId': '531618620634...
#
#                                          eventDetails  \
# 0   {'subgroupNameKey': 'ITF Dominican Republic 03...
# 1   {'subgroupNameKey': 'French Open Men Singles, ...
# 2   {'subgroupNameKey': 'MLB, American League East...
# 3   {'subgroupNameKey': 'NHL, Eastern_conference_f...
# 4   {'subgroupNameKey': 'Mountain West Conference,...
# 5   {'subgroupNameKey': 'MLB, American League West...
# 6   {'subgroupNameKey': 'MLB, American League West...
# 7   {'subgroupNameKey': 'MLB, National League West...
# 8   {'subgroupNameKey': 'MLB, National League West...
# 9   {'subgroupNameKey': 'Liga Profesional, Regular...
# 10  {'subgroupNameKey': 'Primera B Nacional', 'blo...
# 11  {'subgroupNameKey': 'LigaPro Primera A, Primer...
# 12  {'subgroupNameKey': 'Primera Division, Apertur...
# 13  {'subgroupNameKey': 'Liga Profesional, Regular...
# 14  {'subgroupNameKey': 'ATP Challenger Little Roc...
# 15  {'subgroupNameKey': 'ATP Challenger Little Roc...
# 16  {'subgroupNameKey': 'Primera Division, Regular...
# 17  {'subgroupNameKey': 'Brasileiro Serie B, Regul...
#
#                                 sportCurrentGameState  \
# 0   {'updatedAt': '0', 'netSportCurrentGameState':...
# 1   {'updatedAt': '0', 'netSportCurrentGameState':...
# 2   {'updatedAt': '1716761368404', 'baseballCurren...
# 3                                                 NaN
# 4   {'updatedAt': '1716761207464', 'baseballCurren...
# 5   {'updatedAt': '1716761322708', 'baseballCurren...
# 6   {'updatedAt': '1716761371661', 'baseballCurren...
# 7   {'updatedAt': '1716761375159', 'baseballCurren...
# 8   {'updatedAt': '1716761377732', 'baseballCurren...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  {'updatedAt': '1716761371893', 'netSportCurren...
# 15  {'updatedAt': '1716761358839', 'netSportCurren...
# 16                                                NaN
# 17                                                NaN
#
#             lastModifiedTime  \
# 0   2024-05-26T22:09:24.366Z
# 1   2024-05-26T22:08:58.168Z
# 2   2024-05-26T22:09:38.553Z
# 3   2024-05-26T22:09:06.082Z
# 4   2024-05-26T22:06:47.845Z
# 5   2024-05-26T22:08:43.402Z
# 6   2024-05-26T22:09:32.379Z
# 7   2024-05-26T22:09:35.742Z
# 8   2024-05-26T22:09:38.316Z
# 9   2024-05-26T22:09:27.601Z
# 10  2024-05-26T22:09:17.022Z
# 11  2024-05-26T22:09:15.480Z
# 12  2024-05-26T22:09:28.822Z
# 13  2024-05-26T22:09:15.134Z
# 14  2024-05-26T22:09:32.842Z
# 15  2024-05-26T22:09:26.129Z
# 16  2024-05-26T22:09:24.098Z
# 17  2024-05-26T22:09:25.038Z
#
#                                             eventTags  \
# 0   [awayParticipantStateLocation:UNKNOWN, venueSt...
# 1   [awayParticipantStateLocation:OTHER, venueStat...
# 2   [homeParticipantStateLocation:US-IL, venueStat...
# 3   [homeParticipantStateLocation:US-FL, awayParti...
# 4   [college, awayParticipantStateLocation:US-CA, ...
# 5   [venueStateLocation:US-CA, awayParticipantStat...
# 6   [venueStateLocation:US-CA, homeParticipantStat...
# 7   [venueStateLocation:US-CA, awayParticipantStat...
# 8   [homeParticipantStateLocation:US-AZ, awayParti...
# 9   [sgp-pre, awayParticipantStateLocation:OTHER, ...
# 10  [sgp-pre, awayParticipantStateLocation:OTHER, ...
# 11  [sgp-pre, awayParticipantStateLocation:OTHER, ...
# 12  [sgp-pre, awayParticipantStateLocation:OTHER, ...
# 13  [sgp-pre, awayParticipantStateLocation:OTHER, ...
# 14  [venueStateLocation:US-AR, awayParticipantStat...
# 15  [venueStateLocation:US-AR, awayParticipantStat...
# 16  [sgp-pre, awayParticipantStateLocation:OTHER, ...
# 17  [sgp-pre, awayParticipantStateLocation:OTHER, ...
#
#                                 aggregatedEventPoints  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   {'total': {'home': {'CORNER': 4, 'YELLOW_CARD'...
# 10  {'total': {'home': {'CORNER': 3, 'YELLOW_CARD'...
# 11  {'total': {'home': {'CORNER': 5, 'YELLOW_CARD'...
# 12  {'total': {'home': {'CORNER': 0, 'YELLOW_CARD'...
# 13  {'total': {'home': {'CORNER': 1, 'YELLOW_CARD'...
# 14                                                NaN
# 15                                                NaN
# 16  {'total': {'home': {'CORNER': 6, 'YELLOW_CARD'...
# 17  {'total': {'home': {'CORNER': 1, 'YELLOW_CARD'...
#
#                              eventMetadata
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14  {'event-widget': {'providerId': '71'}}
# 15  {'event-widget': {'providerId': '71'}}
# 16                                     NaN
# 17                                     NaN
#
# [18 rows x 22 columns]

# %%
filename = f'data/tipico_data_{datetime.now().strftime("%Y%m%d%H%M%S")}.csv'

# %%
df.to_csv(filename)
